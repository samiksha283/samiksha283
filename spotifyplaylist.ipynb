# %%
#from dotenv import load_dotenv
from requests import post, get
import os
import base64
import json
import pandas as pd

#load_dotenv()

#getting client_id and secret from environment variables file
client_id = "your_client_id"
client_secret =  "your_secret_var"

# %%
def get_token():

    #Visit https://developer.spotify.com/documentation/web-api/tutorials/client-credentials-flow for more information

    #base64 encoding
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode('utf-8')
    auth_base64 = str(base64.b64encode(auth_bytes), 'utf-8')

    url = 'https://accounts.spotify.com/api/token'

    headers = {'Authorization': 'Basic ' + auth_base64, 'Content-Type': 'application/x-www-form-urlencoded'}

    data = {'grant_type': 'client_credentials'}

    result = post(url, headers = headers, data = data)
    json_result = json.loads(result.content)
    token = json_result['access_token']
    return token

def get_auth_header(token):
    return {'Authorization': 'Bearer ' + token}

# %% [markdown]
# Function to get all songs from a playlist, returns a dictionary with track name and id

# %%
def get_playlist(playlist_id, limit=100, fields='items(track(id,name,external_urls))', offset=0, display=True):

    headers = get_auth_header(get_token())

    url = f'https://api.spotify.com/v1/playlists/{playlist_id}/tracks?fields={fields}&limit={limit}&offset={offset}'

    result = get(url, headers=headers)
    json_result = json.loads(result.content)
    track_info = json_result['items']

    track_id_list = []
    track_name_list = []
    tracks={}

    for i in range(len(track_info)):

        if(display):
            print("\n", i+1, " . ", track_info[i]['track']['name'], " | ", end=" ")
            print(track_info[i]['track']['id'], " | ", end=" ")
            print(track_info[i]['track']['external_urls']['spotify'])

        track_id_list.append(track_info[i]['track']['id'])
        track_name_list.append(track_info[i]['track']['name'])

    tracks = dict(zip(track_name_list, track_id_list))
    return tracks


# Angry Playlist - https://open.spotify.com/playlist/0KPEhXA3O9jHFtpd1Ix5OB
tracks = get_playlist(playlist_id="0KPEhXA3O9jHFtpd1Ix5OB", display=False)
print(tracks)
# Out:
# {'Shit Luck': '3b1UyW9VxSymsahmyL3qCD', 'Smells Like Teen Spirit': '5ghIJDpPoe3CfHMGu71E6T', 'You Know How I Do': '2OOM9QIzL3xwS0ODsjxUV4', 'Basket Case': '6L89mwZXSOwYl76YXfX13s', 'The Futile': '6Ng8VpVdgIVmJw4HY4eId9', 'Sail': '5xhQChGGhKLWqBqX4XhtYE', 'Break Stuff': '2YC6ET3q1F29B0V7UcPV70', 'I Hate Everything About You': '6rUp7v3l8yC4TKxAAR5Bmx', 'Worst Behavior': '6oF3Es1YzzmLKjGBfThUvD', 'Seventy Times 7': '78HsNTKVNADOaGxS41OSW7', "I've Had It": '5b0kcwMjAES1SKEHBxQHAJ', "I've Been Tired": '2RYe8B8dEfsqzwQYFaKNfD', 'You Oughta Know': '17ZAZ24Eyh5fKqQ06u4R3d', 'Look Back in Anger - 1999 Remaster': '5HKi6OsSg3qngxfuZeLmyX', 'Last Resort': '5eek2X5459T1HoYJk2CKXv', 'Hit Me With Your Best Shot - 1999 Digital Remaster': '7nrtHjt4Vk4Z5jMHOwaS8F', "I'm Shipping Up To Boston": '6Wze1mFZVcT3fj8hTKnBSz', 'Black Skinhead': '722tgOgdIbNe3BEyLnejw4', 'I Fought The Law': '2LWJJNFtrg6PytOdAGrxQB', 'Take Me Out': '6ooluO7DiEhI1zmK94nRCM', 'Revolution - Remastered 2009': '3UDmHZcBTQp8Iu8droNtUl', 'Drop The World': '3e21cX0CVwzkQXiHz7WUQZ', 'You Make Me Sick - Radio Mix': '6z8WLLLb2kaWRXXF1WmicO', 'You Fucked Up': '0gnvI2vSWIacE3hgLbuWtn', 'In the End': '60a0Rd6pjrkxjPbaKzXjfq', 'You Make Me Sick': '4PzzPMbvYYDUMGHiZU5Uwp', 'Party Up': '4Ew4HyNmZkSH91EPzjuTu4', 'Who Gon Stop Me': '3U9yv46nVSn3PkLsVcNIcA', 'The Kill': '0lP4HYLmvowOKdsQ7CVkuq', "There's No 'I' In Team": '2jB5zEq75RfO5MvRqsxXYT', 'Enter Sandman': '1hKdDCpiI9mqz1jVHRKG0E', 'The Way I Am': '23wfXwnsPZYe5A1xXRHb3J', 'Everything Sux': '0LDAMbrDwcMlH94AG9VYwW', 'Complicated': '5xEM5hIgJ1jjgcEBfpkt2F'}

# %% [markdown]
# Function to get recomendations

# %%
def get_recomendations(limit = 20, market = 'IN', seed_artists = None,
  seed_genres = 'classical, country', seed_tracks = None, max_acousticness = None,
  max_danceability = None, max_energy = None,
  max_instrumentalness = None, max_key = None, max_liveness = None,
  max_loudness = None, max_mode = None, max_popularity = None,
  max_speechiness = None, max_tempo = None,
  max_time_signature = None, max_valence = None,
  min_acousticness = None, min_danceability = None,
   min_energy = None,
  min_instrumentalness = None, min_key = None, min_liveness = None,
  min_loudness = None, min_mode = None, min_popularity = None,
  min_speechiness = None, min_tempo = None,
   min_valence = None,
  target_acousticness = None, target_danceability = None,
  target_energy = None, target_loudness = None,
  target_instrumentalness = None, target_key = None,
  target_liveness = None, target_mode = None,
  target_popularity = None, target_speechiness = None,
  target_tempo = None,
  target_valence = None, token = get_token()):

    headers = get_auth_header(token)

    url = 'https://api.spotify.com/v1/recommendations'

    query = f'?limit={limit}&market=IN'\
    f'{f"&target_valence={target_valence}" if target_valence else ""}'\
    f'{f"&target_loudness={target_loudness}" if target_loudness else ""}'\
    f'{f"&target_instrumentalness={target_instrumentalness}" if target_instrumentalness else ""}'\
    f'{f"&target_speechiness={target_speechiness}" if target_speechiness else ""}'\
    f'{f"&target_acousticness={target_acousticness}" if target_acousticness else ""}'\
    f'{f"&target_tempo={target_tempo}" if target_tempo else ""}'\
    f'{f"&target_liveness={target_liveness}" if target_liveness else ""}'\
    f'{f"&target_energy={target_energy}" if target_energy else ""}'\
    f'{f"&target_popularity={target_popularity}" if target_popularity else ""}'\
    f'{f"&target_danceability={target_danceability}" if target_danceability else ""}'\
    f'{f"&target_mode={target_mode}" if target_mode else ""}'\
    f'{f"&target_key={target_key}" if target_key else ""}'\
    f'{f"&seed_artists={seed_artists}" if seed_artists else ""}'\
    f'{f"&seed_genres={seed_genres}" if seed_genres else ""}'\
    f'{f"&seed_tracks={seed_tracks}" if seed_tracks else ""}'

    print(query)

    query_url = url + query
    result = get(query_url, headers = headers)
    json_result = json.loads(result.content)
    print (result)
    track_info = json_result['tracks']

    for i in range(len(track_info)):
        print("\n", i+1, " . ", track_info[i]['name'], " | ", end=" ")
        print(track_info[i]['artists'][0]['name'], end=" ")
        print(track_info[i]['external_urls']['spotify'])

# %% [markdown]
# Function to get details about the tracks, returns dataframe

# %%
def get_song_details(playlist_id):

    headers = get_auth_header(get_token())

    tracks = get_playlist(playlist_id=playlist_id, display=False)

    ids = list(tracks.values())

    ids = str(ids)[1:-1].replace("'","").replace(" ","")

    url = f'https://api.spotify.com/v1/audio-features?ids={ids}'


    result = get(url, headers=headers)
    json_result = json.loads(result.content)

    df = pd.DataFrame.from_dict(json_result['audio_features'])
    return df

# %% [markdown]
# ## Emotion - Anger

# %% [markdown]
# Angry Playlist data - https://open.spotify.com/playlist/0KPEhXA3O9jHFtpd1Ix5OB

# %%
# Angry Playlist - https://open.spotify.com/playlist/0KPEhXA3O9jHFtpd1Ix5OB
angry_df = get_song_details('0KPEhXA3O9jHFtpd1Ix5OB')
angry_df.describe()
#angry_df.head()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     34.000000  34.000000  34.000000  34.000000  34.000000    34.000000
# mean       0.504824   0.832676   5.323529  -5.945529   0.676471     0.110179
# std        0.176102   0.113312   3.327758   2.582891   0.474858     0.090551
# min        0.179000   0.435000   0.000000 -12.089000   0.000000     0.029600
# 25%        0.374500   0.781750   3.000000  -6.764750   0.000000     0.053925
# 50%        0.500000   0.858500   4.000000  -5.584500   1.000000     0.068750
# 75%        0.598500   0.909500   8.000000  -4.123000   1.000000     0.156750
# max        0.825000   0.997000  11.000000  -1.629000   1.000000     0.340000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     34.000000         34.000000  34.000000  34.000000   34.000000
# mean       0.067805          0.037413   0.268194   0.500824  120.343382
# std        0.126797          0.149430   0.189280   0.176570   32.323499
# min        0.000025          0.000000   0.045100   0.237000   77.987000
# 25%        0.001172          0.000000   0.136750   0.351000   93.649500
# 50%        0.004170          0.000008   0.242500   0.463000  113.352500
# 75%        0.082925          0.000273   0.333000   0.638750  129.938500
# max        0.557000          0.643000   0.868000   0.954000  201.830000
#
#          duration_ms  time_signature
# count      34.000000       34.000000
# mean   207971.617647        3.941176
# std     58194.581451        0.238833
# min     85867.000000        3.000000
# 25%    173646.500000        4.000000
# 50%    208953.000000        4.000000
# 75%    246847.000000        4.000000
# max    331573.000000        4.000000

# %% [markdown]
# Angry Playlist 2 - https://open.spotify.com/playlist/4zZpffTnguBELBde2Ar30Z

# %%
angry_df = get_song_details('4zZpffTnguBELBde2Ar30Z')
angry_df.describe()
#angry_df.head()
# Out:
#        danceability      energy         key    loudness        mode  \
# count    100.000000  100.000000  100.000000  100.000000  100.000000
# mean       0.630360    0.814200    5.160000   -4.397270    0.690000
# std        0.147734    0.167916    3.876164    3.216536    0.464823
# min        0.214000    0.309000    0.000000  -11.444000    0.000000
# 25%        0.564500    0.721500    1.000000   -6.631000    0.000000
# 50%        0.652000    0.869500    4.500000   -4.564500    1.000000
# 75%        0.734250    0.951750    9.000000   -1.451500    1.000000
# max        0.918000    0.995000   11.000000    2.044000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   100.000000    100.000000        100.000000  100.000000  100.000000
# mean      0.194950      0.064905          0.170683    0.285999    0.464223
# std       0.137746      0.090288          0.312268    0.198167    0.222155
# min       0.035600      0.000004          0.000000    0.031100    0.039800
# 25%       0.082625      0.005347          0.000000    0.117750    0.282000
# 50%       0.152000      0.029450          0.000237    0.238000    0.492000
# 75%       0.278000      0.075300          0.108750    0.415500    0.644250
# max       0.695000      0.413000          0.966000    0.798000    0.965000
#
#             tempo    duration_ms  time_signature
# count  100.000000     100.000000      100.000000
# mean   130.549640  153851.280000        3.910000
# std     31.951767   40656.821246        0.378594
# min     74.997000   82731.000000        1.000000
# 25%    104.186750  123313.750000        4.000000
# 50%    126.002000  150605.000000        4.000000
# 75%    155.835500  176275.250000        4.000000
# max    200.049000  274133.000000        4.000000

# %% [markdown]
# Angry Songs Recomendations Playlist 1

# %%
#FYI seed_genre matters a lot

get_recomendations(seed_genres="rock,metal,heavy-metal,death-metal,punk-rock", limit=15, target_popularity=100, target_danceability=0.5, target_energy=0.8, target_loudness=-5.94, target_acousticness=0.06, target_valence=0.5, target_tempo=120.34)
# Out:
# ?limit=15&market=IN&target_valence=0.5&target_loudness=-5.94&target_acousticness=0.06&target_tempo=120.34&target_energy=0.8&target_popularity=100&target_danceability=0.5&seed_genres=rock,metal,heavy-metal,death-metal,punk-rock
# <Response [200]>
#
#  1  .  I Hate Everything About You  |  Three Days Grace https://open.spotify.com/track/6rUp7v3l8yC4TKxAAR5Bmx
#
#  2  .  The Philosopher  |  Death https://open.spotify.com/track/7zKweXON2KcgXizqUcu7lf
#
#  3  .  All Along the Watchtower  |  Jimi Hendrix https://open.spotify.com/track/2aoo2jlRnM3A0NyLQqMN2f
#
#  4  .  Your Treachery Will Die WIth You  |  Dying Fetus https://open.spotify.com/track/4FZoFK86X6Wd1csU9afTIA
#
#  5  .  On Melancholy Hill  |  Gorillaz https://open.spotify.com/track/0q6LuUqGLUiCPP1cbdwFs3
#
#  6  .  Counting Stars  |  OneRepublic https://open.spotify.com/track/2tpWsVSb9UEmDRxAl1zhX1
#
#  7  .  Girls & Boys  |  Good Charlotte https://open.spotify.com/track/65mxB9IWpmVo4qUjdGSxRB
#
#  8  .  In the End  |  Linkin Park https://open.spotify.com/track/60a0Rd6pjrkxjPbaKzXjfq
#
#  9  .  I'm Just a Kid  |  Simple Plan https://open.spotify.com/track/6otiaV2fagE3s8IvP6WkwG
#
#  10  .  From Womb to Waste  |  Dying Fetus https://open.spotify.com/track/7juCZpPi4C3Lsr8jiCfVVT
#
#  11  .  Domination  |  Pantera https://open.spotify.com/track/769cLRTw2y6KRdkFWFkxtu
#
#  12  .  Wake Me up When September Ends  |  Green Day https://open.spotify.com/track/3ZffCQKLFLUvYM59XKLbVm
#
#  13  .  Fight For Your Right  |  Beastie Boys https://open.spotify.com/track/5NLuC70kZQv8q34QyQa1DP
#
#  14  .  Carry on Wayward Son  |  Kansas https://open.spotify.com/track/4DMKwE2E2iYDKY01C335Uw
#
#  15  .  You've Got Another Thing Coming  |  Judas Priest https://open.spotify.com/track/4f3RDq9nYPBeR1yMSgnmBm

# %% [markdown]
# Angry Song Recommendation Playlist 2

# %%
get_recomendations(seed_genres="rock,metal,heavy-metal,death-metal,punk-rock", limit=15, target_popularity=90, target_danceability=0.73, target_energy=0.9, target_loudness=-5.39, target_acousticness=0.06, target_valence=0.47, target_tempo=150.34)
# Out:
# ?limit=15&market=IN&target_valence=0.47&target_loudness=-5.39&target_acousticness=0.06&target_tempo=150.34&target_energy=0.9&target_popularity=90&target_danceability=0.73&seed_genres=rock,metal,heavy-metal,death-metal,punk-rock
# <Response [200]>
#
#  1  .  Overactive Imagination  |  Death https://open.spotify.com/track/7gRKe3yTuARYOJwF6ecGzg
#
#  2  .  Sugar, We're Goin Down  |  Fall Out Boy https://open.spotify.com/track/2TfSHkHiFO4gRztVIkggkE
#
#  3  .  Symphony Of Destruction  |  Megadeth https://open.spotify.com/track/4YJZjINIhakR98fnz1Pvup
#
#  4  .  Subjected to a Beating  |  Dying Fetus https://open.spotify.com/track/7dU9Z24yR9AKuS9cAe2Tj7
#
#  5  .  Sex on Fire  |  Kings of Leon https://open.spotify.com/track/0ntQJM78wzOLVeCUAW7Y45
#
#  6  .  Girls & Boys  |  Good Charlotte https://open.spotify.com/track/65mxB9IWpmVo4qUjdGSxRB
#
#  7  .  The Philosopher  |  Death https://open.spotify.com/track/7zKweXON2KcgXizqUcu7lf
#
#  8  .  Breaking the Law  |  Judas Priest https://open.spotify.com/track/2RaA6kIcvomt77qlIgGhCT
#
#  9  .  Everlong  |  Foo Fighters https://open.spotify.com/track/07q6QTQXyPRCf7GbLakRPr
#
#  10  .  Sacrificial Suicide  |  Deicide https://open.spotify.com/track/2kW45RgvG6cGkyAfq9ZlsZ
#
#  11  .  Symphony Of Destruction  |  Megadeth https://open.spotify.com/track/51TG9W3y9qyO8BY5RXKgnZ
#
#  12  .  Ritual  |  Ghost https://open.spotify.com/track/4hxd9xX8SNH0R2XSrXRATW
#
#  13  .  Sacred Serenity  |  Death https://open.spotify.com/track/5I2nvva658EdhIAtRQadWG
#
#  14  .  Song #3  |  Stone Sour https://open.spotify.com/track/5jsDxDkJ1PqyYUWhDMr86B
#
#  15  .  Rebel Yell  |  Billy Idol https://open.spotify.com/track/4TIJ7zSBNejpoIPaWpWRKc

# %% [markdown]
# ## Emotion - Sad

# %% [markdown]
# Sad Playlist 1 - https://open.spotify.com/playlist/6yYA6aUGp8qUTgQWWYkPkP

# %%
sad_df = get_song_details('6yYA6aUGp8qUTgQWWYkPkP')
sad_df.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     99.000000  99.000000  99.000000  99.000000  99.000000    99.000000
# mean       0.509051   0.368999   5.757576  -9.334697   0.696970     0.061184
# std        0.126507   0.159908   3.341425   3.119774   0.461907     0.067460
# min        0.236000   0.084800   0.000000 -18.435000   0.000000     0.027400
# 25%        0.394000   0.269000   4.000000 -10.773500   0.000000     0.031950
# 50%        0.507000   0.361000   6.000000  -8.920000   1.000000     0.038200
# 75%        0.615000   0.455500   9.000000  -7.349500   1.000000     0.050700
# max        0.791000   0.888000  11.000000  -3.536000   1.000000     0.438000
#
#        acousticness  instrumentalness  liveness    valence       tempo  \
# count     99.000000         99.000000  99.00000  99.000000   99.000000
# mean       0.678555          0.011431   0.14110   0.268887  114.019010
# std        0.264070          0.069308   0.09197   0.125034   32.617866
# min        0.046700          0.000000   0.06530   0.080800   67.016000
# 25%        0.567000          0.000000   0.09740   0.169000   83.702500
# 50%        0.767000          0.000000   0.11300   0.246000  111.825000
# 75%        0.889500          0.000026   0.14250   0.355500  137.859500
# max        0.978000          0.657000   0.76400   0.621000  180.917000
#
#          duration_ms  time_signature
# count      99.000000       99.000000
# mean   216138.050505        3.898990
# std     33776.148386        0.391099
# min    144377.000000        3.000000
# 25%    196265.000000        4.000000
# 50%    215507.000000        4.000000
# 75%    236206.500000        4.000000
# max    298899.000000        5.000000

# %% [markdown]
# Jazzy Sad Songs almost romanticised

# %%
get_recomendations(seed_genres="emo,blues", limit=15, target_popularity=90, target_danceability=0.48, target_energy=0.32, target_loudness=-10.49, target_acousticness=0.76, target_valence=0.11, target_tempo=115)
# Out:
# ?limit=15&market=IN&target_valence=0.11&target_loudness=-10.49&target_acousticness=0.76&target_tempo=115&target_energy=0.32&target_popularity=90&target_danceability=0.48&seed_genres=emo,blues
# <Response [200]>
#
#  1  .  Gravity  |  John Mayer https://open.spotify.com/track/3SktMqZmo3M9zbB7oKMIF7
#
#  2  .  I Won't Give Up  |  Jason Mraz https://open.spotify.com/track/05pKAafT85jeeNhZ6kq7HT
#
#  3  .  St James Infirmary  |  Hugh Laurie https://open.spotify.com/track/4eAlHTYUZvllH2dE2juVQZ
#
#  4  .  Brown Sugar  |  ZZ Top https://open.spotify.com/track/5H0buOvucTuvEvrJFxtftl
#
#  5  .  Give Me One Reason  |  Tracy Chapman https://open.spotify.com/track/4vDBJeeQCbhP9FaPPMsYkY
#
#  6  .  Misguided Ghosts  |  Paramore https://open.spotify.com/track/2VYqkb77OjToeRAnMNd4yU
#
#  7  .  Say Something  |  A Great Big World https://open.spotify.com/track/6Vc5wAMmXdKIAM7WUoEb7N
#
#  8  .  The Scientist  |  Coldplay https://open.spotify.com/track/75JFxkI2RXiU7L9VXzMkle
#
#  9  .  All of Me  |  John Legend https://open.spotify.com/track/3U4isOIWM3VvDubwSI3y7a
#
#  10  .  Skinny Love  |  Birdy https://open.spotify.com/track/4RL77hMWUq35NYnPLXBpih
#
#  11  .  The A Team  |  Ed Sheeran https://open.spotify.com/track/1VdZ0vKfR5jneCmWIUAMxK
#
#  12  .  A Lack of Color  |  Death Cab for Cutie https://open.spotify.com/track/1nuqzCMgj2lxZCmpdCmIGv
#
#  13  .  When I Was Your Man  |  Bruno Mars https://open.spotify.com/track/0nJW01T7XtvILxQgC5J7Wh
#
#  14  .  Lenny  |  Stevie Ray Vaughan https://open.spotify.com/track/1MIDCw2NTW3Dtn9c6ohSC8
#
#  15  .  9 Crimes  |  Damien Rice https://open.spotify.com/track/5GZEeowhvSieFDiR8fQ2im

# %% [markdown]
# Sad Playlist 2 - https://open.spotify.com/playlist/6vEYfoIeIIzC87k94JDcYj

# %%
sad_df = get_song_details('6vEYfoIeIIzC87k94JDcYj')
sad_df.describe()
# Out:
#        danceability      energy         key   loudness        mode  \
# count    100.000000  100.000000  100.000000  100.00000  100.000000
# mean       0.512000    0.469166    5.820000   -9.39252    0.420000
# std        0.131753    0.200132    3.497127    4.46723    0.496045
# min        0.198000    0.017400    0.000000  -29.85000    0.000000
# 25%        0.408750    0.365000    3.000000  -10.93450    0.000000
# 50%        0.535000    0.486500    5.000000   -8.54450    0.000000
# 75%        0.616250    0.626500    9.000000   -6.61075    1.000000
# max        0.761000    0.843000   11.000000   -3.29300    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   100.000000    100.000000        100.000000  100.000000  100.000000
# mean      0.043229      0.581261          0.053797    0.125796    0.356518
# std       0.028186      0.277161          0.202424    0.062019    0.177594
# min       0.023700      0.018900          0.000000    0.057700    0.041900
# 25%       0.030700      0.367750          0.000000    0.091825    0.234000
# 50%       0.035400      0.631000          0.000004    0.111000    0.338000
# 75%       0.044600      0.820000          0.000193    0.133500    0.474000
# max       0.272000      0.988000          0.972000    0.420000    0.802000
#
#             tempo    duration_ms  time_signature
# count  100.000000     100.000000      100.000000
# mean   110.435710  238915.920000        3.750000
# std     28.561243   74372.176864        0.729951
# min     64.934000   41750.000000        1.000000
# 25%     86.449000  198120.500000        4.000000
# 50%    102.183500  242777.000000        4.000000
# 75%    131.104250  276900.500000        4.000000
# max    180.042000  470500.000000        5.000000

# %% [markdown]
# Quite Sad Lyrics (giving sad genre gives genuinely depressing lyrics however they're often anger sad, may or may not use acooustic)

# %%
get_recomendations(seed_genres="pop,emo,blues,acoustic,grunge", limit=15, target_popularity=90, target_danceability=0.51, target_energy=0.46, target_loudness=-9.39, target_acousticness=0.58, target_valence=0.35, target_tempo=110.4)
# Out:
# ?limit=15&market=IN&target_valence=0.35&target_loudness=-9.39&target_acousticness=0.58&target_tempo=110.4&target_energy=0.46&target_popularity=90&target_danceability=0.51&seed_genres=pop,emo,blues,acoustic,grunge
# <Response [200]>
#
#  1  .  Electric (feat. Khalid)  |  Alina Baraz https://open.spotify.com/track/2mj7x99sNUsVHPBRK51zlG
#
#  2  .  Tenerife Sea  |  Ed Sheeran https://open.spotify.com/track/1HbcclMpw0q2WDWpdGCKdS
#
#  3  .  Juke Jam (feat. Justin Bieber & Towkio)  |  Chance the Rapper https://open.spotify.com/track/3eze1OsZ1rqeXkKStNfTmi
#
#  4  .  Sweet Creature  |  Harry Styles https://open.spotify.com/track/5kRPPEWFJIMox5qIkQkiz5
#
#  5  .  Red House  |  Jimi Hendrix https://open.spotify.com/track/3PwKz7ML8VnNAp15OzIMWG
#
#  6  .  The Man Who Sold The World  |  Nirvana https://open.spotify.com/track/15VRO9CQwMpbqUYA7e6Hwg
#
#  7  .  Too Good At Goodbyes  |  Sam Smith https://open.spotify.com/track/1mXVgsBdtIVeCLJnSnmtdV
#
#  8  .  Give Me Love  |  Ed Sheeran https://open.spotify.com/track/0SuG9kyzGRpDqrCWtgD6Lq
#
#  9  .  Wrecking Ball  |  Miley Cyrus https://open.spotify.com/track/2vwlzO0Qp8kfEtzTsCXfyE
#
#  10  .  LOYALTY. FEAT. RIHANNA.  |  Kendrick Lamar https://open.spotify.com/track/6SwRhMLwNqEi6alNPVG00n
#
#  11  .  Good Riddance (Time of Your Life)  |  Green Day https://open.spotify.com/track/6ORqU0bHbVCRjXm9AjyHyZ
#
#  12  .  All Apologies  |  Nirvana https://open.spotify.com/track/3bH8PZsfbCRIoeNiFm7JmU
#
#  13  .  Oceans  |  Pearl Jam https://open.spotify.com/track/0LBmvPJYmtEJ7kkWvc3kbT
#
#  14  .  The A Team  |  Ed Sheeran https://open.spotify.com/track/1VdZ0vKfR5jneCmWIUAMxK
#
#  15  .  The Scientist  |  Coldplay https://open.spotify.com/track/75JFxkI2RXiU7L9VXzMkle

# %% [markdown]
# ## Emotion - Happy

# %% [markdown]
# Happy Playlist 1 - https://open.spotify.com/playlist/0jrlHA5UmxRxJjoykf7qRY

# %%
happy_df = get_song_details('0jrlHA5UmxRxJjoykf7qRY')
happy_df.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count      55.00000  55.000000  55.000000  55.000000  55.000000    55.000000
# mean        0.62160   0.621655   4.963636  -6.248455   0.745455     0.060415
# std         0.15312   0.176409   3.839192   2.553548   0.439620     0.049270
# min         0.23000   0.128000   0.000000 -18.717000   0.000000     0.023200
# 25%         0.53750   0.521500   1.000000  -6.937000   0.500000     0.034350
# 50%         0.67200   0.640000   5.000000  -6.049000   1.000000     0.045200
# 75%         0.72900   0.762500   8.000000  -4.789500   1.000000     0.065950
# max         0.85600   0.884000  11.000000  -2.278000   1.000000     0.276000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     55.000000         55.000000  55.000000  55.000000   55.000000
# mean       0.260230          0.000676   0.155238   0.492613  116.663382
# std        0.248711          0.003703   0.140265   0.242538   26.940976
# min        0.001730          0.000000   0.034400   0.038200   68.534000
# 25%        0.064300          0.000000   0.095950   0.340000   96.463500
# 50%        0.180000          0.000000   0.115000   0.486000  114.988000
# 75%        0.421000          0.000008   0.165500   0.657500  132.497500
# max        0.894000          0.026000   0.988000   0.952000  186.003000
#
#          duration_ms  time_signature
# count      55.000000       55.000000
# mean   216665.927273        3.890909
# std     32622.796627        0.458368
# min    156205.000000        1.000000
# 25%    195720.000000        4.000000
# 50%    211560.000000        4.000000
# 75%    241801.000000        4.000000
# max    290840.000000        4.000000

# %% [markdown]
# white club dance happy songs, however if you remove the current genres and use indian, it suggested chikni chameli which is always a good sign

# %%
get_recomendations(seed_genres="happy,dance,funk", limit=15, target_popularity=90, target_danceability=0.75, target_energy=0.76, target_loudness=-4.24, target_acousticness=0.32, target_valence=0.49, target_tempo=116.4)
# Out:
# ?limit=15&market=IN&target_valence=0.49&target_loudness=-4.24&target_acousticness=0.32&target_tempo=116.4&target_energy=0.76&target_popularity=90&target_danceability=0.75&seed_genres=happy,dance,funk
# <Response [200]>
#
#  1  .  Everything  |  Michael Bublé https://open.spotify.com/track/4T6HLdP6OcAtqC6tGnQelG
#
#  2  .  Outside (feat. Ellie Goulding)  |  Calvin Harris https://open.spotify.com/track/7MmG8p0F9N3C4AXdK6o6Eb
#
#  3  .  The Fox (What Does the Fox Say?)  |  Ylvis https://open.spotify.com/track/5HOpkTTVcmZHnthgyxrIL8
#
#  4  .  California Gurls  |  Katy Perry https://open.spotify.com/track/6tS3XVuOyu10897O3ae7bi
#
#  5  .  Electric Feel  |  MGMT https://open.spotify.com/track/3FtYbEfBqAlGO46NUDQSAt
#
#  6  .  Marry You  |  Bruno Mars https://open.spotify.com/track/6SKwQghsR8AISlxhcwyA9R
#
#  7  .  Show Me Love  |  Robin S https://open.spotify.com/track/4t0UsYzmmmZRMTWn77jiGF
#
#  8  .  I Need Your Love (feat. Ellie Goulding)  |  Calvin Harris https://open.spotify.com/track/05SBRd4fXgn8FX7bf8BCAE
#
#  9  .  Pocketful of Sunshine  |  Natasha Bedingfield https://open.spotify.com/track/4hjuUelurEBKlqpJPJ77Iw
#
#  10  .  Teenage Dream  |  Katy Perry https://open.spotify.com/track/55qBw1900pZKfXJ6Q9A2Lc
#
#  11  .  Stronger (What Doesn't Kill You)  |  Kelly Clarkson https://open.spotify.com/track/1nInOsHbtotAmEOQhtvnzP
#
#  12  .  Ocean Drive  |  Duke Dumont https://open.spotify.com/track/0b6wdul3A5sQNpIOv03OxP
#
#  13  .  Shuffle  |  Bombay Bicycle Club https://open.spotify.com/track/4yYvWFUWMaKMXtoJKJnmZk
#
#  14  .  Sweet Nothing (feat. Florence Welch)  |  Calvin Harris https://open.spotify.com/track/24LS4lQShWyixJ0ZrJXfJ5
#
#  15  .  Crazy  |  Gnarls Barkley https://open.spotify.com/track/1vxw6aYJls2oq3gW0DujAo

# %%
get_recomendations(seed_genres="dancehall,hip-hop,pop,guitar", limit=15, target_popularity=100, target_danceability=0.66, target_energy=0.765, target_loudness=-4.81, target_acousticness=0.01, target_valence=0.56, target_tempo=186.4, target_liveness=0.35)
# Out:
# ?limit=15&market=IN&target_valence=0.56&target_loudness=-4.81&target_acousticness=0.01&target_tempo=186.4&target_liveness=0.35&target_energy=0.765&target_popularity=100&target_danceability=0.66&seed_genres=dancehall,hip-hop,pop,guitar
# <Response [200]>
#
#  1  .  Roar  |  Katy Perry https://open.spotify.com/track/6F5c58TMEs1byxUstkzVeM
#
#  2  .  Ain't My Fault  |  Zara Larsson https://open.spotify.com/track/0ADG9OgdVTL7fgREP75BrZ
#
#  3  .  Black and Yellow  |  Wiz Khalifa https://open.spotify.com/track/5A6OHHy73AR5tLxgTc98zz
#
#  4  .  How You Remind Me  |  Nickelback https://open.spotify.com/track/0gmbgwZ8iqyMPmXefof8Yf
#
#  5  .  679 (feat. Remy Boyz)  |  Fetty Wap https://open.spotify.com/track/5NQbUaeTEOGdD6hHcre0dZ
#
#  6  .  Either Way (feat. Joey Bada$$)  |  Snakehips https://open.spotify.com/track/3nodtPfXcok53E8Uze8gvD
#
#  7  .  Powerglide (feat. Juicy J) - From SR3MM  |  Rae Sremmurd https://open.spotify.com/track/1BuZAIO8WZpavWVbbq3Lci
#
#  8  .  Cherry Pie  |  Warrant https://open.spotify.com/track/7LygtNjQ65PSdzVjUnHXQb
#
#  9  .  No Games  |  Serani https://open.spotify.com/track/3WU2blK7YBcugEEU9CATvF
#
#  10  .  Counting Stars  |  OneRepublic https://open.spotify.com/track/2tpWsVSb9UEmDRxAl1zhX1
#
#  11  .  Romping Shop (feat. Spice)  |  Vybz Kartel https://open.spotify.com/track/6D7jtD4GbpX1ujF1KqPr7Y
#
#  12  .  Collard Greens  |  ScHoolboy Q https://open.spotify.com/track/0zO8ctW0UiuOefR87OeJOZ
#
#  13  .  7/11  |  Beyoncé https://open.spotify.com/track/02M6vucOvmRfMxTXDUwRXu
#
#  14  .  The One I Love - Remastered 2012  |  R.E.M. https://open.spotify.com/track/2fdfsGuqb6SBX5ocoBWHUd
#
#  15  .  Plain Jane  |  A$AP Ferg https://open.spotify.com/track/4dVpf9jZjcORqGTLUaeYj9

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## Emotion - Fear

# %% [markdown]
# Twisted horror Playlist - https://open.spotify.com/playlist/5AM4lgcUAw5sokybXj3ny7

# %%
fear_df = get_song_details('5AM4lgcUAw5sokybXj3ny7')
fear_df.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     78.000000  78.000000  78.000000  78.000000  78.000000    78.000000
# mean       0.610103   0.740590   5.346154  -5.101808   0.423077     0.093497
# std        0.125681   0.132894   3.635421   1.670068   0.497245     0.073925
# min        0.342000   0.396000   0.000000  -9.348000   0.000000     0.028600
# 25%        0.550250   0.642750   2.000000  -6.223000   0.000000     0.043150
# 50%        0.593500   0.771000   5.000000  -5.010500   0.000000     0.067250
# 75%        0.700250   0.846250   8.000000  -3.958500   1.000000     0.105750
# max        0.927000   0.965000  11.000000  -0.818000   1.000000     0.325000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     78.000000         78.000000  78.000000  78.000000   78.000000
# mean       0.113711          0.007837   0.197541   0.492500  121.161564
# std        0.172967          0.045588   0.140285   0.232236   30.256336
# min        0.000247          0.000000   0.043300   0.061400   68.039000
# 25%        0.012000          0.000000   0.105000   0.321000   95.041750
# 50%        0.046650          0.000000   0.149000   0.506500  120.008500
# 75%        0.121500          0.000051   0.266000   0.630250  143.746500
# max        0.870000          0.388000   0.799000   0.967000  190.109000
#
#          duration_ms  time_signature
# count      78.000000       78.000000
# mean   205913.294872        3.974359
# std     37421.896899        0.159085
# min    109302.000000        3.000000
# 25%    185142.250000        4.000000
# 50%    202357.000000        4.000000
# 75%    222025.750000        4.000000
# max    363521.000000        4.000000

# %% [markdown]
# Hard to decide genres

# %%
get_recomendations(seed_artists="5TvFfw1MgSntdU9A7yncyA,7qrYuWFTRINeUML3ptoSEk", seed_genres='', limit=15, target_popularity=85, target_danceability=0.61, target_energy=0.74, target_loudness=-5.101, target_acousticness=0.113, target_valence=0.49, target_tempo=121.1)
# Out:
# ?limit=15&market=IN&target_valence=0.49&target_loudness=-5.101&target_acousticness=0.113&target_tempo=121.1&target_energy=0.74&target_popularity=85&target_danceability=0.61&seed_artists=5TvFfw1MgSntdU9A7yncyA,7qrYuWFTRINeUML3ptoSEk
# <Response [200]>
#
#  1  .  PRINCE OF DARKNESS  |  SHADXWBXRN https://open.spotify.com/track/3F8ydJz1se1vIxZTRcRjIJ
#
#  2  .  Emotion  |  MC Andelko https://open.spotify.com/track/0sV4pmvaL0OfhmTbGcGUxo
#
#  3  .  Override  |  KSLV Noh https://open.spotify.com/track/6O4oKV3btLiEtOgEuplIUn
#
#  4  .  RAVE  |  Dxrk ダーク https://open.spotify.com/track/01kfSdF9zfcDLri5sSWEoL
#
#  5  .  BABYDOLL (Speed)  |  Ari Abdul https://open.spotify.com/track/5K3SJuYEkvvrLbzOjPyRi1
#
#  6  .  Ars Goetia  |  akiaura https://open.spotify.com/track/6E52kq40quOLAbIiqSkNix
#
#  7  .  WARNING  |  MC ORSEN https://open.spotify.com/track/5z7RJpEWyWIEUPEXzvM7PJ
#
#  8  .  1917  |  ENVXSKY https://open.spotify.com/track/2d8DIPj6hXEJh2AIr1oiS1
#
#  9  .  Polarity  |  Assalm https://open.spotify.com/track/5m7YVR8cx2CLAQ4WJ5KBl8
#
#  10  .  Like Wooh Wooh  |  Rnbstylerz https://open.spotify.com/track/2DjZ7Ytv2UDKXSoQXTXPkN
#
#  11  .  Keep Up The Pace  |  Stonebank https://open.spotify.com/track/359dqboVug8CoRUE8WNVGf
#
#  12  .  Nothing There (Instrumental)  |  Fulvietto The Grimer https://open.spotify.com/track/4ylGpIkzRMbaDTgweCog8q
#
#  13  .  The System Has Failed  |  Karl Casey https://open.spotify.com/track/3UQbvuOlFOXVcHbVmAG7pK
#
#  14  .  FACE TO FACE  |  KUTE https://open.spotify.com/track/6xJhueZ6Wt0aoNkMTv9DZ0
#
#  15  .  End of Line - Remixed by Photek  |  Daft Punk https://open.spotify.com/track/2UBYw2qf9PkvoKQ610ocft

# %% [markdown]
# Horror Playlist 2 - https://open.spotify.com/playlist/70c2IG67uDLGIiJ3sJH76k

# %%
fear_df = get_song_details('70c2IG67uDLGIiJ3sJH76k')
fear_df.describe()
# Out:
#        danceability     energy        key  loudness       mode  speechiness  \
# count     57.000000  57.000000  57.000000  57.00000  57.000000    57.000000
# mean       0.532667   0.398219   5.859649 -13.50186   0.578947     0.082156
# std        0.192983   0.238618   3.382933   6.08021   0.498117     0.094926
# min        0.120000   0.020600   0.000000 -25.69400   0.000000     0.025700
# 25%        0.396000   0.186000   3.000000 -18.01100   0.000000     0.037500
# 50%        0.569000   0.411000   7.000000 -14.06800   1.000000     0.049100
# 75%        0.690000   0.539000   8.000000  -9.08100   1.000000     0.079600
# max        0.881000   0.919000  11.000000  -1.87000   1.000000     0.507000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     57.000000         57.000000  57.000000  57.000000   57.000000
# mean       0.586421          0.457874   0.179126   0.362244  108.768491
# std        0.365103          0.408676   0.126617   0.301974   25.686681
# min        0.000779          0.000000   0.071100   0.032700   61.007000
# 25%        0.259000          0.003120   0.098100   0.076700   91.470000
# 50%        0.687000          0.388000   0.120000   0.260000  110.023000
# 75%        0.911000          0.874000   0.222000   0.630000  127.965000
# max        0.996000          0.971000   0.648000   0.967000  175.236000
#
#          duration_ms  time_signature
# count      57.000000       57.000000
# mean   170717.771930        3.789474
# std     86087.613648        0.452645
# min     32014.000000        3.000000
# 25%    104973.000000        4.000000
# 50%    148040.000000        4.000000
# 75%    209829.000000        4.000000
# max    402952.000000        5.000000

# %% [markdown]
# Easier to give users calming songs when they feel fearful - https://open.spotify.com/playlist/0cj48sijCRDJ3Hatx1k1vJ

# %%
fear_df = get_song_details('0cj48sijCRDJ3Hatx1k1vJ')
fear_df.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     64.000000  64.000000  64.000000  64.000000  64.000000    64.000000
# mean       0.593500   0.547063   5.953125  -7.856656   0.718750     0.063233
# std        0.144844   0.206091   3.760402   3.761413   0.453163     0.049715
# min        0.332000   0.020300   0.000000 -23.163000   0.000000     0.025600
# 25%        0.467500   0.422000   3.000000  -9.246750   0.000000     0.038250
# 50%        0.598000   0.576000   6.500000  -7.214500   1.000000     0.048950
# 75%        0.723000   0.667750   9.250000  -5.338750   1.000000     0.065050
# max        0.872000   0.941000  11.000000  -2.958000   1.000000     0.334000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     64.000000         64.000000  64.000000  64.000000   64.000000
# mean       0.432146          0.030521   0.180677   0.406300  123.121719
# std        0.303651          0.123513   0.141958   0.216101   30.195238
# min        0.000038          0.000000   0.044700   0.089900   76.074000
# 25%        0.201500          0.000000   0.099500   0.227250  101.571750
# 50%        0.376500          0.000003   0.116000   0.376500  116.432000
# 75%        0.655000          0.000693   0.206750   0.551250  144.017750
# max        0.962000          0.743000   0.696000   0.867000  202.466000
#
#          duration_ms  time_signature
# count      64.000000        64.00000
# mean   192055.453125         3.71875
# std     51912.501504         0.57649
# min     63664.000000         1.00000
# 25%    167804.750000         3.00000
# 50%    184900.000000         4.00000
# 75%    220258.250000         4.00000
# max    357931.000000         5.00000

# %%
get_recomendations(seed_genres="study,chill,piano", limit=15, target_popularity=90, target_danceability=0.46, target_energy=0.44, target_loudness=-7.9, target_acousticness=0.43, target_valence=0.60, target_tempo=123.1, target_instrumentalness=0.03)
# Out:
# ?limit=15&market=IN&target_valence=0.6&target_loudness=-7.9&target_instrumentalness=0.03&target_acousticness=0.43&target_tempo=123.1&target_energy=0.44&target_popularity=90&target_danceability=0.46&seed_genres=study,chill,piano
# <Response [200]>
#
#  1  .  Vienna  |  Billy Joel https://open.spotify.com/track/4U45aEWtQhrm8A5mxPaFZ7
#
#  2  .  Lucky  |  Jason Mraz https://open.spotify.com/track/0IktbUcnAGrvD03AWnz3Q8
#
#  3  .  If I Ain't Got You  |  Alicia Keys https://open.spotify.com/track/3XVBdLihbNbxUwZosxcGuJ
#
#  4  .  Daughters  |  John Mayer https://open.spotify.com/track/5FPnjikbwlDMULCCCa6ZCJ
#
#  5  .  Let It Go - From "Frozen"/Soundtrack Version  |  Idina Menzel https://open.spotify.com/track/0qcr5FMsEO85NAQjrlDRKo
#
#  6  .  Viva La Vida  |  Coldplay https://open.spotify.com/track/1mea3bSkSGXuIRvnydlB5b
#
#  7  .  Just the Way You Are  |  Billy Joel https://open.spotify.com/track/49MHCPzvMLXhRjDantBMVH
#
#  8  .  Young And Beautiful  |  Lana Del Rey https://open.spotify.com/track/2nMeu6UenVvwUktBCpLMK9
#
#  9  .  Good Riddance (Time of Your Life)  |  Green Day https://open.spotify.com/track/6ORqU0bHbVCRjXm9AjyHyZ
#
#  10  .  Half of My Heart  |  John Mayer https://open.spotify.com/track/7hR5toSPEgwFZ78jfHdANM
#
#  11  .  Bad Day  |  Daniel Powter https://open.spotify.com/track/0mUyMawtxj1CJ76kn9gIZK
#
#  12  .  I'm Yours  |  Jason Mraz https://open.spotify.com/track/1EzrEOXmMH3G43AXT1y7pA
#
#  13  .  New York State of Mind  |  Billy Joel https://open.spotify.com/track/3zIIjuvnDALIs9WNl3w3uT
#
#  14  .  Clocks  |  Coldplay https://open.spotify.com/track/0BCPKOYdS2jbQ8iyB56Zns
#
#  15  .  Brick  |  Ben Folds Five https://open.spotify.com/track/4jKq1e80xAYixkIwt6YyV1

# %% [markdown]
# ## Emotion - Surprise

# %%
get_recomendations(seed_genres="pop", seed_artists="06HL4z0CvFAxyc27GXpf02", limit=5, target_popularity=100)
# Out:
# ?limit=5&market=IN&target_popularity=100&seed_artists=06HL4z0CvFAxyc27GXpf02&seed_genres=pop
# <Response [200]>
#
#  1  .  Believer  |  Imagine Dragons https://open.spotify.com/track/0pqnGHJpmpxLKifKRmU6WP
#
#  2  .  vampire  |  Olivia Rodrigo https://open.spotify.com/track/3k79jB4aGmMDUQzEwa46Rz
#
#  3  .  Do I Wanna Know?  |  Arctic Monkeys https://open.spotify.com/track/5FVd6KXrgO9B3JPmC8OPst
#
#  4  .  Seven (feat. Latto) (Explicit Ver.)  |  Jung Kook https://open.spotify.com/track/7x9aauaA9cu6tyfpHnqDLo
#
#  5  .  One Kiss (with Dua Lipa)  |  Calvin Harris https://open.spotify.com/track/7ef4DlsgrMEH11cDZd32M6

# %% [markdown]
# ## Emotion - Neutral

# %% [markdown]
# Lofi Playlist - https://open.spotify.com/album/5GuzM0RPjiuYRZVHz81LrA

# %%
neutral_df = get_song_details('0cj48sijCRDJ3Hatx1k1vJ')
neutral_df.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     64.000000  64.000000  64.000000  64.000000  64.000000    64.000000
# mean       0.593500   0.547063   5.953125  -7.856656   0.718750     0.063233
# std        0.144844   0.206091   3.760402   3.761413   0.453163     0.049715
# min        0.332000   0.020300   0.000000 -23.163000   0.000000     0.025600
# 25%        0.467500   0.422000   3.000000  -9.246750   0.000000     0.038250
# 50%        0.598000   0.576000   6.500000  -7.214500   1.000000     0.048950
# 75%        0.723000   0.667750   9.250000  -5.338750   1.000000     0.065050
# max        0.872000   0.941000  11.000000  -2.958000   1.000000     0.334000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     64.000000         64.000000  64.000000  64.000000   64.000000
# mean       0.432146          0.030521   0.180677   0.406300  123.121719
# std        0.303651          0.123513   0.141958   0.216101   30.195238
# min        0.000038          0.000000   0.044700   0.089900   76.074000
# 25%        0.201500          0.000000   0.099500   0.227250  101.571750
# 50%        0.376500          0.000003   0.116000   0.376500  116.432000
# 75%        0.655000          0.000693   0.206750   0.551250  144.017750
# max        0.962000          0.743000   0.696000   0.867000  202.466000
#
#          duration_ms  time_signature
# count      64.000000        64.00000
# mean   192055.453125         3.71875
# std     51912.501504         0.57649
# min     63664.000000         1.00000
# 25%    167804.750000         3.00000
# 50%    184900.000000         4.00000
# 75%    220258.250000         4.00000
# max    357931.000000         5.00000

# %%
get_recomendations(seed_genres="classical,sleep,study", seed_artists="0Nrx6TQe5XBFEuRBhZTGpC", limit=5, target_danceability=0.56, target_energy=0.54, target_loudness=-7.85, target_acousticness=0.43, target_valence=0.40, target_tempo=123.1, target_instrumentalness=0.03)
# Out:
# ?limit=5&market=IN&target_valence=0.4&target_loudness=-7.85&target_instrumentalness=0.03&target_acousticness=0.43&target_tempo=123.1&target_energy=0.54&target_danceability=0.56&seed_artists=0Nrx6TQe5XBFEuRBhZTGpC&seed_genres=classical,sleep,study
# <Response [200]>
#
#  1  .  Let It Go - From "Frozen"/Soundtrack Version  |  Idina Menzel https://open.spotify.com/track/0qcr5FMsEO85NAQjrlDRKo
#
#  2  .  Capriccio Espagnol, Op. 34: I. Alborada  |  Nikolai Rimsky-Korsakov https://open.spotify.com/track/1mBCmEfsVz5Wm77dJcxcYH
#
#  3  .  Daughters  |  John Mayer https://open.spotify.com/track/5FPnjikbwlDMULCCCa6ZCJ
#
#  4  .  To the East Lofi  |  Jamie Lofi https://open.spotify.com/track/4UPXUw1FAQLqHZzkBbczvK
#
#  5  .  how do I get my brain back  |  a girl and a cat https://open.spotify.com/track/1WaEevGmRXVepVwY7oKzGx

# %% [markdown]
# ## Emotion - Disgust

# %% [markdown]
# Disgust / disgusted girlies - https://open.spotify.com/playlist/5MRWF7JwMVERvDSTM9W2b9

# %%
disgust_df = get_song_details('5MRWF7JwMVERvDSTM9W2b9')
disgust_df.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     29.000000  29.000000  29.000000  29.000000  29.000000    29.000000
# mean       0.630552   0.661724   5.482759  -5.538931   0.586207     0.141566
# std        0.125046   0.132506   3.581906   2.030308   0.501230     0.115213
# min        0.418000   0.310000   0.000000 -12.695000   0.000000     0.027100
# 25%        0.557000   0.599000   2.000000  -6.179000   0.000000     0.066800
# 50%        0.635000   0.698000   6.000000  -5.415000   1.000000     0.094300
# 75%        0.707000   0.743000   8.000000  -3.932000   1.000000     0.169000
# max        0.875000   0.881000  11.000000  -2.853000   1.000000     0.475000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     29.000000         29.000000  29.000000  29.000000   29.000000
# mean       0.124339          0.001491   0.217917   0.511414  124.324483
# std        0.154975          0.007735   0.215128   0.193898   32.294667
# min        0.003120          0.000000   0.032200   0.131000   61.657000
# 25%        0.012000          0.000000   0.093400   0.361000   97.973000
# 50%        0.057900          0.000002   0.123000   0.535000  120.003000
# 75%        0.186000          0.000027   0.185000   0.637000  150.022000
# max        0.579000          0.041700   0.737000   0.851000  179.974000
#
#          duration_ms  time_signature
# count      29.000000       29.000000
# mean   194642.551724        3.931034
# std     36200.604522        0.257881
# min    120666.000000        3.000000
# 25%    177200.000000        4.000000
# 50%    193147.000000        4.000000
# 75%    212027.000000        4.000000
# max    272373.000000        4.000000

# %%
url = 'https://api.spotify.com/v1/audio-features?ids=6GUiIbJ834FcHewby3PwV0'

result = get(url, headers=get_auth_header(get_token()))
json_result = json.loads(result.content)
json_result
# Out:
# {'audio_features': [{'danceability': 0.64,
#    'energy': 0.553,
#    'key': 2,
#    'loudness': -6.42,
#    'mode': 0,
#    'speechiness': 0.0411,
#    'acousticness': 0.0579,
#    'instrumentalness': 0,
#    'liveness': 0.0914,
#    'valence': 0.486,
#    'tempo': 81.992,
#    'type': 'audio_features',
#    'id': '6GUiIbJ834FcHewby3PwV0',
#    'uri': 'spotify:track:6GUiIbJ834FcHewby3PwV0',
#    'track_href': 'https://api.spotify.com/v1/tracks/6GUiIbJ834FcHewby3PwV0',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GUiIbJ834FcHewby3PwV0',
#    'duration_ms': 148471,
#    'time_signature': 4}]}

# %%
get_recomendations(seed_artists="5KKpBU5eC2tJDzf0wmlRp2,2W8yFh0Ga6Yf3jiayVxwkE,26VFTg2z8YR0cCuwLzESi2", seed_genres='', limit=15, target_danceability=0.64, target_energy=0.58, target_loudness=-6.538, target_acousticness=0.05, target_valence=0.48, target_tempo=90, target_instrumentalness=0.0014)
# Out:
# ?limit=15&market=IN&target_valence=0.48&target_loudness=-6.538&target_instrumentalness=0.0014&target_acousticness=0.05&target_tempo=90&target_energy=0.58&target_danceability=0.64&seed_artists=5KKpBU5eC2tJDzf0wmlRp2,2W8yFh0Ga6Yf3jiayVxwkE,26VFTg2z8YR0cCuwLzESi2
# <Response [200]>
#
#  1  .  Breakfast  |  Dove Cameron https://open.spotify.com/track/6GUiIbJ834FcHewby3PwV0
#
#  2  .  Flip A Switch. (feat. Coi Leray) - Remix  |  RAYE https://open.spotify.com/track/72b7GzsnUAjsk5I56hLkjp
#
#  3  .  Woman of the Hour  |  Stela Cole https://open.spotify.com/track/1UNPpd8XbOUkC4MryeQtYR
#
#  4  .  Keep On Coming  |  Gia Woods https://open.spotify.com/track/6rjQSnaaTkdFSdKWLfEeR6
#
#  5  .  Be Kind (with Halsey)  |  Marshmello https://open.spotify.com/track/3Z8FwOEN59mRMxDCtb8N0A
#
#  6  .  stupid  |  Tate McRae https://open.spotify.com/track/4k3uABcX9iaGlt5pRJhumi
#
#  7  .  madhouse  |  Nessa Barrett https://open.spotify.com/track/1s9e1EBT6eYbDOneeBB6r0
#
#  8  .  Black Hole Friend  |  Chymes https://open.spotify.com/track/78irBGVYCFS8UeuEjatKzR
#
#  9  .  People I Don't Like  |  UPSAHL https://open.spotify.com/track/5srKMwXoeyrRnyTnNbpgIW
#
#  10  .  Still Learning  |  Halsey https://open.spotify.com/track/2Mfv5HaqnI18Q9JRv9hqnn
#
#  11  .  Bounce Right Back  |  Jaira Burns https://open.spotify.com/track/64VLbbcT3Ph84t1edH9uNf
#
#  12  .  Born Ready - From "Marvel Rising"  |  Dove Cameron https://open.spotify.com/track/5C1PksOQ542mrdjr3BX86P
#
#  13  .  Most Girls  |  Hailee Steinfeld https://open.spotify.com/track/10GJQkjRJcZhGTLagFOC62
#
#  14  .  Terms and Conditions  |  Mahalia https://open.spotify.com/track/0gR8uAS5TNzsuWzWw9OR8C
#
#  15  .  pl4yg1rl  |  Lolo Zouaï https://open.spotify.com/track/6hULiSmcrKKWVx74G1gPr6
